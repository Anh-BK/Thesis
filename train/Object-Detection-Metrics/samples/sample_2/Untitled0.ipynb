# %%
from google.colab import drive
drive.mount("/content/my_drive/")
# Out:
# Mounted at /content/my_drive/

# %%
# %cd my_drive/MyDrive/Project_2020/code/old_version/YOLOv3-custom-training/Object-Detection-Metrics/samples/sample_2/
# Out:
# /content/my_drive/MyDrive/Project_2020/code/old_version/YOLOv3-custom-training/Object-Detection-Metrics/samples/sample_2

# %%
# !python sample_2.py
# Out:
# <Figure size 640x480 with 1 Axes>
# Average precision values per class:
#
# object: 0.245687
